# %% [markdown]
# <h2> Data Wrangling</h2>
# <hr>
# <h6>praticals</h6>

# %% [markdown]
# <h2>Table of content</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ul>
#     <li><a href="#identify_handle_missing_values">Identify and handle missing values</a>
#         <ul>
#             <li><a href="#identify_missing_values">Identify missing values</a></li>
#             <li><a href="#deal_missing_values">Deal with missing values</a></li>
#             <li><a href="#correct_data_format">Correct data format</a></li>
#         </ul>
#     </li>
#     <li><a href="#data_standardization">Data standardization</a></li>
#     <li><a href="#data_normalization">Data Normalization (centering/scaling)</a></li>
#     <li><a href="#binning">Binning</a></li>
#     <li><a href="#indicator">Indicator variable</a></li>
# </ul>
# </div>
#
# <hr>

# %% [markdown]
# <h3> importing necessary libraries</h3>

# %%
#import libraries 
import  pandas as pd 
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('autos_imports-85.csv', names=cols)
print(data.shape)
data.head()
# Out:
# (206, 26)
#     symboling  normalized-losses         make  fuel-type  aspiration  \
# 0  %symboling  normalized-losses         make  fuel-type  aspiration
# 1           3                  ?  alfa-romero        gas         std
# 2           3                  ?  alfa-romero        gas         std
# 3           1                  ?  alfa-romero        gas         std
# 4           2                164         audi        gas         std
#
#    num-of-doors   body-style  drive-wheels engine-location wheel-base  ...  \
# 0  num-of-doors   body-style  drive-wheels      wheel-base     length  ...
# 1           two  convertible           rwd           front      88.60  ...
# 2           two  convertible           rwd           front      88.60  ...
# 3           two    hatchback           rwd           front      94.50  ...
# 4          four        sedan           fwd           front      99.80  ...
#
#    engine-size fuel-system    bore             stroke    compression-ratio  \
# ...

# %% [markdown]
# <b> how to work with missing data ?<b>
#     <ol>
#         <li> dentify missing data </li>
#         <li>deal with missing data</li>
#         <li>correct data fromat </li>
#     </ol>

# %%
#using  NaN function 
data = data.replace("?", np.NaN)
data.head()
# Out:
#     symboling  normalized-losses         make  fuel-type  aspiration  \
# 0  %symboling  normalized-losses         make  fuel-type  aspiration
# 1           3                NaN  alfa-romero        gas         std
# 2           3                NaN  alfa-romero        gas         std
# 3           1                NaN  alfa-romero        gas         std
# 4           2                164         audi        gas         std
#
#    num-of-doors   body-style  drive-wheels engine-location wheel-base  ...  \
# 0  num-of-doors   body-style  drive-wheels      wheel-base     length  ...
# 1           two  convertible           rwd           front      88.60  ...
# 2           two  convertible           rwd           front      88.60  ...
# 3           two    hatchback           rwd           front      94.50  ...
# 4          four        sedan           fwd           front      99.80  ...
#
#    engine-size fuel-system    bore             stroke    compression-ratio  \
# ...

# %% [markdown]
# <h4>Evaluating for Missing Data</h4>
#
# The missing values are converted to Python's default. We use Python's built-in functions to identify these missing values. There are two methods to detect missing data:
# <ol>
#     <li><b>.isnull()</b></li>
#     <li><b>.notnull()</b></li>
# </ol>

# %%
data.isnull().any().any()
# Out:
# True

# %%
# Count missing vaues in each column 
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           1
# price                 5
# dtype: int64

# %% [markdown]
# <h6>Based on the summary above, each column has 205 rows of data, seven columns containing missing data:</h6>
# <ol>
#     <li>"normalized-losses": 41 missing data</li>
#     <li>"num-of-doors": 2 missing data</li>
#     <li>"bore": 4 missing data</li>
#     <li>"stroke" : 4 missing data</li>
#     <li>"horsepower": 2 missing data</li>
#     <li>"peak-rpm": 2 missing data</li>
#     <li> "highway-mpg": 1 missing data</li>
#     <li>"price": 5 missing data</li>
# </ol>

# %% [markdown]
# <h3 id="deal_missing_values">Deal with missing data</h3>
# <b>How to deal with missing data?</b>
#
# <ol>
#     <li>drop data<br>
#         a. drop the whole row<br>
#         b. drop the whole column
#     </li>
#     <li>replace data<br>
#         a. replace it by mean<br>
#         b. replace it by frequency<br>
#         c. replace it based on other functions
#     </li>
# </ol>

# %%
#Calculate the average of the colounmn 
# replace by mean 
avg_norm_loss = data['normalized-losses'].astype("float").mean()
avg_norm_loss
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8345/3954430193.py in <module>
#       1 #Calculate the average of the colounmn
#       2 # replace by mean
# ----> 3 avg_norm_loss = data['normalized-losses'].astype("float").mean()
#       4 avg_norm_loss
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...
